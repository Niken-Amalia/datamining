# %%
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression (n_samples=50, n_features=1, noise=0.2)
pyplot.scatter(X_test,y_test)
pyplot.show()

# %%
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression (n_samples=50, n_features=1, noise=10)
pyplot.scatter(X_test,y_test)
pyplot.show()

# %%
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression (n_samples=50, n_features=1, noise=50)
pyplot.scatter(X_test,y_test)
pyplot.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
#X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
#y = 1 * x_0 + 2 * x_1 + 3
#y = np.dot(X, np.array([1, 2])) + 3
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)
# Out:
# 0.0677543160496541

# %%
reg.coef_
# Out:
# array([13.23908289])

# %%
reg.intercept_
# Out:
# -4.925620903101328

# %%
reg.predict(np.array([[4]]))
# Out:
# array([48.03071065])

# %%
pyplot.scatter(X_test,y_test)
Y_plot = reg.coef_*X_test+reg.intercept_

pyplot.plot(X_test, Y_plot, color="r")
pyplot.show()
